# %%
import awswrangler as wr

# %% [markdown]
# ### Create a connection to Redshift database

# %%
redshift_con = wr.redshift.connect(connection = "adriano_redshift_cluster")

# %% [markdown]
# ### Query existing records in Redshift table

# %%
existing_records_df =  wr.redshift.read_sql_query(sql=
                                 'SELECT * FROM public.category_1', con=redshift_con)
existing_records_df
# Out:
#     catid  catgroup    catname                                     catdesc  \
# 0       1    Sports        MLB                       Major League Baseball
# 1       6     Shows   Musicals                             Musical theatre
# 2      11  Concerts  Classical  All symphony, concerto, and choir concerts
# 3       4    Sports        NBA             National Basketball Association
# 4       7     Shows      Plays                     All non-musical theatre
# 5      10  Concerts       Jazz                  All jazz singers and bands
# 6       3    Sports        NFL                    National Football League
# 7       8     Shows      Opera                   All opera and light opera
# 8       2    Sports        NHL                      National Hockey League
# 9       5    Sports        MLS                         Major League Soccer
# 10      9  Concerts        Pop             All rock and pop music concerts
#
#    date_modified
# 0     2021-03-11
# 1     2021-03-11
# 2     2021-03-11
# 3     2021-03-11
# 4     2021-03-11
# 5     2021-03-11
# 6     2021-03-11
# 7     2021-03-11
# 8     2021-03-11
# 9     2021-03-11
# 10    2021-03-11

# %% [markdown]
# ### Read updated data from S3

# %%
upsert_records_df = wr.s3.read_csv("s3://adriano-datalake-us-east-1/raw/categories/categories.csv")
upsert_records_df
# Out:
#    catid  catgroup        catname  \
# 0     12  Concerts  Electro Swing
# 1     13  Concerts          House
# 2      9  Concerts    Country pop
#
#                                           catdesc date_modified
# 0                Mix of Jazz and Electronic Dance    2023-03-05
# 1                          electronic dance music    2023-03-05
# 2   a fusion genre of country music and pop music    2023-03-05

# %% [markdown]
# ### Upsert To Redshift < 1000 records

# %%
output =wr.redshift.to_sql(df=upsert_records_df, con=redshift_con, 
                     table='category_1',schema='public', mode='upsert',
                     primary_keys=['catid'],use_column_names=True)

# %%
existing_records_df =  wr.redshift.read_sql_query(sql=
                        'SELECT * FROM public.category_1',
                        con=redshift_con)
existing_records_df
# Out:
#     catid  catgroup        catname  \
# 0       3    Sports            NFL
# 1       8     Shows          Opera
# 2       2    Sports            NHL
# 3       5    Sports            MLS
# 4      13  Concerts          House
# 5       9  Concerts    Country pop
# 6       1    Sports            MLB
# 7       6     Shows       Musicals
# 8      11  Concerts      Classical
# 9       4    Sports            NBA
# 10      7     Shows          Plays
# 11     10  Concerts           Jazz
# 12     12  Concerts  Electro Swing
#
#                                            catdesc date_modified
# 0                         National Football League    2021-03-11
# 1                        All opera and light opera    2021-03-11
# 2                           National Hockey League    2021-03-11
# 3                              Major League Soccer    2021-03-11
# 4                           electronic dance music    2023-03-05
# 5    a fusion genre of country music and pop music    2023-03-05
# 6                            Major League Baseball    2021-03-11
# 7                                  Musical theatre    2021-03-11
# 8       All symphony, concerto, and choir concerts    2021-03-11
# 9                  National Basketball Association    2021-03-11
# 10                         All non-musical theatre    2021-03-11
# 11                      All jazz singers and bands    2021-03-11
# 12                Mix of Jazz and Electronic Dance    2023-03-05

# %% [markdown]
# ### Upsert to Redshift > 1000 Records

# %%
s3_path = 's3://adriano-datalake-us-east-1/raw/temp_path/'
dtype = {'catid':'smallint','catgroup': 'varchar(10)',
        'catname':'varchar(20)','catdesc': 'varchar(50)','date_modified':'date'}

output =wr.redshift.copy(df=upsert_records_df, path=s3_path,
                        con=redshift_con,  table='category_1',
                        schema='public',use_column_names=True, 
                        mode='upsert',primary_keys=['catid'],
                        index=False,
                        dtype=dtype)

# %% [markdown]
# ### Upsert using Latest Date

# %%
upsert_records_date_df = wr.s3.read_csv("s3://adriano-datalake-us-east-1/raw/categories/categories_date_modified.csv")
upsert_records_date_df
# Out:
#    catid  catgroup catname                 catdesc date_modified
# 0     13  Concerts   House  Electronic Dance Music    2023-03-25
# 1      9  Concerts   Plays                     Pop    2023-03-01

# %%
output =wr.redshift.to_sql(df=upsert_records_df, con=redshift_con, 
                    table='category_1',schema='public', mode='upsert', 
                    primary_keys=['catid'],
                    precombine_key='date_modified',
                    use_column_names=True)

# %% [markdown]
# ### Select Final Records from Database

# %%
existing_records_df =  wr.redshift.read_sql_query(sql=
                       'SELECT * FROM public.category_1',
                        con=redshift_con)
existing_records_df
# Out:
#     catid  catgroup        catname  \
# 0       3    Sports            NFL
# 1       8     Shows          Opera
# 2       2    Sports            NHL
# 3       5    Sports            MLS
# 4      12  Concerts  Electro Swing
# 5       1    Sports            MLB
# 6       6     Shows       Musicals
# 7      11  Concerts      Classical
# 8       4    Sports            NBA
# 9       7     Shows          Plays
# 10     10  Concerts           Jazz
# 11     13  Concerts          House
# 12      9  Concerts    Country pop
#
#                                            catdesc date_modified
# 0                         National Football League    2021-03-11
# 1                        All opera and light opera    2021-03-11
# 2                           National Hockey League    2021-03-11
# 3                              Major League Soccer    2021-03-11
# 4                 Mix of Jazz and Electronic Dance    2023-03-05
# 5                            Major League Baseball    2021-03-11
# 6                                  Musical theatre    2021-03-11
# 7       All symphony, concerto, and choir concerts    2021-03-11
# 8                  National Basketball Association    2021-03-11
# 9                          All non-musical theatre    2021-03-11
# 10                      All jazz singers and bands    2021-03-11
# 11                          Electronic Dance Music    2023-03-25
# 12   a fusion genre of country music and pop music    2023-03-05

# %% [markdown]
# ### Close redshift Connection

# %%
redshift_con.close()
